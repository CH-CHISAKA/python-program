# %% [markdown]
# # Question 1
#
# Converting a float into an int

# %%
# Define a variable that will hold the float
pi = 3.142

print("The value of pi is:", pi)
print("The type of pi is:", type(pi))
# Out:
# The value of pi is: 3.142
# The type of pi is: <class 'float'>

# %%
# Converting pi (a float) to an integer
int_pi = int(pi)
print("The value of int_pi is:", int_pi)
print("The type of int_pi is:", type(int_pi))

# Alternative way to convert pi to an integer without creating a new variable
print("The value of int_pi is:", int(pi))
print("The type of int_pi is:", type(int(pi)))
# Out:
# The value of int_pi is: 3
# The type of int_pi is: <class 'int'>
# The value of int_pi is: 3
# The type of int_pi is: <class 'int'>

# %% [markdown]
# # Question 2
#
# Using Booleans (which can take a value of `True` and `False`)
#
# - What happens when you multiply an integer or float by `True`?  What happens when you multiply them by `False`?  How does the answer change if the numbers are positive or negative?
# - What happens when you multiply a string by `True`?  By `False`?

# %%
print(3 * False)  # Output: 0.. why? 
# In Python, the boolean value `False` is treated as `0` when used in arithmetic operations. Therefore, when you multiply `3` by `False`, it is equivalent to multiplying `3` by `0`, which results in `0`.
# Out:
# 0

# %%
print(3 * True)  # Output: 3.. why? 
# In Python, the boolean value `True` is treated as `1` when used in arithmetic operations. Therefore, when you multiply `3` by `True`, it is equivalent to multiplying `3` by `1`, which results in `3`.
# Out:
# 3

# %%
print(type("abc" * False))  # Output: <class 'str'>.. why?
# In Python, when you multiply a string by `False`, it is treated as multiplying the string by `0`. This results in an empty string, which is still of type `str`.
# Out:
# <class 'str'>

# %% [markdown]
# # Question 3
#
# Use the next code cell to create a function `get_expected_cost` that takes as input three variables:
# - `beds` - number of bedrooms (data type float)
# - `baths` - number of bathrooms (data type float)
# - `has_basement` - whether or not the house has a basement (data type boolean)
#
# It should return the expected cost of a house with those characteristics. Assume that:
# - the expected cost for a house with 0 bedrooms and 0 bathrooms, and no basement is 80000,
# - each bedroom adds 30000 to the expected cost,
# - each bathroom adds 10000 to the expected cost, and
# - a basement adds 40000 to the expected cost.
#
# For instance,
# - a house with 1 bedroom, 1 bathroom, and no basement has an expected cost of 80000 + 30000 + 10000 = 120000.  This value will be calculated with `get_expected_cost(1, 1, False)`.
# - a house with 2 bedrooms, 1 bathroom, and a basement has an expected cost of 80000 + 2*30000 + 10000 + 40000 = 190000.  This value will be calculated with `get_expected_cost(2, 1, True)`.
#
# Remember you can always get a hint by uncommenting `q3.hint()` in the code cell following the next!

# %%
def get_expected_cost(beds, baths, has_basement):
    beds= float(beds)
    baths= float(baths)
    has_basement = bool(has_basement)
    cost = 80000 + (beds * 30000) + (baths * 10000) + (has_basement * 40000)
    
    return cost

# %%
print(f"The expected cost of a house with 1 bed, 1 bath, and no basement is: ${get_expected_cost(1, 1, False)}")

print(f"The expected cost of a house with 2 beds, 1 bath, and no basement is: ${get_expected_cost(2, 1, True)}")
# Out:
# The expected cost of a house with 1 bed, 1 bath, and no basement is: $120000.0
# The expected cost of a house with 2 beds, 1 bath, and no basement is: $190000.0

# %%
# Alternative way to convert pi to an integer without creating a new variable

# TODO: Complete the function
def get_expected_cost(beds, baths, has_basement):
    value = 80000 + float(beds * 30000) + float(baths * 10000) 
    
    if has_basement:
        value +=40000
    return value

print(f"The expected cost of a house with 1 bed, 1 bath, and no basement is: ${get_expected_cost(1,1, False)}")
print(f"The expected cost of a house with 2 beds, 1 bath, and a basemen is: ${get_expected_cost(2, 1, True)}")
# Out:
# The expected cost of a house with 1 bed, 1 bath, and no basement is: $120000.0
# The expected cost of a house with 2 beds, 1 bath, and a basemen is: $190000.0

# %% [markdown]
# # Question 4
#
# The code below provides an output of what happens when one adds booleans
#
# NB: Remember
# False = 0
# True = 1

# %%
print(False + False)
print(True + False)
print(False + True)
print(True + True)
print(False + True + True + True)
# Out:
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# # Question 5
#
#
# You own an online shop where you sell rings with custom engravings.  You offer both gold plated and solid gold rings.
# - Gold plated rings have a base cost of \\$50, and you charge \\$7 per engraved unit.
# - Solid gold rings have a base cost of \\$100, and you charge \\$10 per engraved unit.
# - Spaces and punctuation are counted as engraved units.
#
# Write a function `cost_of_project()` that takes two arguments:
# - `engraving` - a Python string with the text of the engraving
# - `solid_gold` - a Boolean that indicates whether the ring is solid gold

# %%
def cost_of_project(engraving, solid_gold):
    if solid_gold:
        cost = 100 + len(engraving) * 10
    else:
        cost = 50 + len(engraving) * 7
    return cost

print(cost_of_project("Happy Birthday", True))
# Out:
# 240

# %% [markdown]
# The next code cell to calculates the cost of engraving 08/10/2000 on a gold plated ring.

# %%
project_two = cost_of_project("08/10/2000", False)
print(project_two)
# Out:
# 120
